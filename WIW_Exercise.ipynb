# %%
#Importing the required libraries
import pandas as pd
import requests
import string

#Downloading the datasets from repo and printing the download status: Successful or Unsuccessful
for char in string.ascii_lowercase:
    url = "https://public.wiwdata.com/engineering-challenge/data/"+str(char)+".csv"
    output_file = str(char)+".csv"
    print(output_file)
    response = requests.get(url)
    if response.status_code == 200:
        with open(output_file, 'wb') as f:
            f.write(response.content)
        print("Download Successful: ",output_file)
    else:
        print("Download Unsuccessful!: ", output_file)
        
#Creating the paths list to upload data into dataframes
paths = []
for char in string.ascii_lowercase:
    path = "C:/Users/biran/Desktop/When I Work Challenge/"+str(char)+".csv"
    paths.append(path)
    print(path)
    
#Creating a dictionary of dataframes with uploaded data from source files
dfs = {}

for x, path in enumerate(paths, 1):
    df_name = f"df_{x}"
    print(df_name)
    dfs[df_name] = pd.read_csv(path)
    
#Pivoting the dataframes to get the necessary columns with correct information
#Then reindexing the dataframe and filling the NaN with 0 and changing the data type to int
#Then storing the new dataframes to new dictionary of dataframes called pivoted_dfs
pivoted_dfs = {}
for y, df in enumerate(dfs,1):
    pivoted_df = dfs[f'df_'+str(y)].pivot(index='user_id', columns='path', values='length') 
    pivoted_df = pivoted_df.reset_index()
    pivoted_df.fillna(0, inplace=True)
    pivoted_df = pivoted_df.astype(int)
    pivoted_dfs[f'df{y+1}_pivoted'] = pivoted_df
    print(f'df{y+1}_pivoted')

#Concatenated all the Dataframes into one final dataframe and exported the csv file
#Reason for choosing concatenation is all the files had unique IDs and same feature columns i.e. 14
concatenated_df = pd.concat(pivoted_dfs.values(), ignore_index = True)
concatenated_df.to_csv("Merged_file.csv", index=False) 
print('Script ran successfully, data download, pivot and merge is complete!')
# Out:
# a.csv
# Download Successful:  a.csv
# b.csv
# Download Successful:  b.csv
# c.csv
# Download Successful:  c.csv
# d.csv
# Download Successful:  d.csv
# e.csv
# Download Successful:  e.csv
# f.csv
# Download Successful:  f.csv
# g.csv
# Download Successful:  g.csv
# h.csv
# Download Successful:  h.csv
# i.csv
# Download Successful:  i.csv
# j.csv
# Download Successful:  j.csv
# k.csv
# Download Successful:  k.csv
# l.csv
# Download Successful:  l.csv
# m.csv
# Download Successful:  m.csv
# n.csv
# Download Successful:  n.csv
# o.csv
# Download Successful:  o.csv
# p.csv
# Download Successful:  p.csv
# q.csv
# Download Successful:  q.csv
# r.csv
# Download Successful:  r.csv
# s.csv
# Download Successful:  s.csv
# t.csv
# Download Successful:  t.csv
# u.csv
# Download Successful:  u.csv
# v.csv
# Download Successful:  v.csv
# w.csv
# Download Successful:  w.csv
# x.csv
# Download Successful:  x.csv
# y.csv
# Download Successful:  y.csv
# z.csv
# Download Successful:  z.csv
# C:/Users/biran/Desktop/When I Work Challenge/a.csv
# C:/Users/biran/Desktop/When I Work Challenge/b.csv
# C:/Users/biran/Desktop/When I Work Challenge/c.csv
# C:/Users/biran/Desktop/When I Work Challenge/d.csv
# C:/Users/biran/Desktop/When I Work Challenge/e.csv
# C:/Users/biran/Desktop/When I Work Challenge/f.csv
# C:/Users/biran/Desktop/When I Work Challenge/g.csv
# C:/Users/biran/Desktop/When I Work Challenge/h.csv
# C:/Users/biran/Desktop/When I Work Challenge/i.csv
# C:/Users/biran/Desktop/When I Work Challenge/j.csv
# C:/Users/biran/Desktop/When I Work Challenge/k.csv
# C:/Users/biran/Desktop/When I Work Challenge/l.csv
# C:/Users/biran/Desktop/When I Work Challenge/m.csv
# C:/Users/biran/Desktop/When I Work Challenge/n.csv
# C:/Users/biran/Desktop/When I Work Challenge/o.csv
# C:/Users/biran/Desktop/When I Work Challenge/p.csv
# C:/Users/biran/Desktop/When I Work Challenge/q.csv
# C:/Users/biran/Desktop/When I Work Challenge/r.csv
# C:/Users/biran/Desktop/When I Work Challenge/s.csv
# C:/Users/biran/Desktop/When I Work Challenge/t.csv
# C:/Users/biran/Desktop/When I Work Challenge/u.csv
# C:/Users/biran/Desktop/When I Work Challenge/v.csv
# C:/Users/biran/Desktop/When I Work Challenge/w.csv
# C:/Users/biran/Desktop/When I Work Challenge/x.csv
# C:/Users/biran/Desktop/When I Work Challenge/y.csv
# C:/Users/biran/Desktop/When I Work Challenge/z.csv
# df_1
# df_2
# df_3
# df_4
# df_5
# df_6
# df_7
# df_8
# df_9
# df_10
# df_11
# df_12
# df_13
# df_14
# df_15
# df_16
# df_17
# df_18
# df_19
# df_20
# df_21
# df_22
# df_23
# df_24
# df_25
# df_26
# df2_pivoted
# df3_pivoted
# df4_pivoted
# df5_pivoted
# df6_pivoted
# df7_pivoted
# df8_pivoted
# df9_pivoted
# df10_pivoted
# df11_pivoted
# df12_pivoted
# df13_pivoted
# df14_pivoted
# df15_pivoted
# df16_pivoted
# df17_pivoted
# df18_pivoted
# df19_pivoted
# df20_pivoted
# df21_pivoted
# df22_pivoted
# df23_pivoted
# df24_pivoted
# df25_pivoted
# df26_pivoted
# df27_pivoted
# Script ran successfully, data download, pivot and merge is complete!
